# %% [markdown]
# <a href="https://colab.research.google.com/github/SARANGIVenkateshwarlu/-Excel-Tutorial/blob/main/tutorials/streamlit_notebooks/SENTIMENT_EN_FINANCE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![JohnSnowLabs](https://nlp.johnsnowlabs.com/assets/images/logo.png)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/streamlit_notebooks/SENTIMENT_EN_FINANCE.ipynb)

# %% [markdown]
# # **Sentiment Analysis of Financial news**

# %% [markdown]
# ## 1. Colab Setup

# %%
# Install PySpark and Spark NLP
! pip install -q pyspark==3.3.0 spark-nlp==4.2.8

# Install Spark NLP Display lib
! pip install --upgrade -q spark-nlp-display

# %%
import json
import pandas as pd
import numpy as np

import sparknlp
import pyspark.sql.functions as F

from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
from sparknlp.annotator import *
from sparknlp.base import *
from sparknlp.pretrained import PretrainedPipeline
from pyspark.sql.types import StringType, IntegerType

# %%
spark = sparknlp.start()

print("Spark NLP version", sparknlp.version())
print("Apache Spark version:", spark.version)

spark
# Out:
# Spark NLP version 4.2.8
# Apache Spark version: 3.3.0
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a9a4bdcd6895:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark NLP</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 2. Some sample examples

# %%
text_list = [
"""In April 2005 , Neste separated from its parent company , Finnish energy company Fortum , and became listed on the Helsinki Stock Exchange .""",
"""Finnish IT solutions provider Affecto Oyj HEL : AFE1V said today its slipped to a net loss of EUR 115,000 USD 152,000 in the second quarter of 2010 from a profit of EUR 845,000 in the corresponding period a year earlier .""",
"""10 February 2011 - Finnish media company Sanoma Oyj HEL : SAA1V said yesterday its 2010 net profit almost tripled to EUR297 .3 m from EUR107 .1 m for 2009 and announced a proposal for a raised payout .""",
"""Profit before taxes decreased by 9 % to EUR 187.8 mn in the first nine months of 2008 , compared to EUR 207.1 mn a year earlier .""",
"""The world 's second largest stainless steel maker said net profit in the three-month period until Dec. 31 surged to euro603 million US$ 781 million , or euro3 .33 US$ 4.31 per share , from euro172 million , or euro0 .94 per share , the previous year .""",
"""TietoEnator signed an agreement to acquire Indian research and development ( R&D ) services provider and turnkey software solutions developer Fortuna Technologies Pvt. Ltd. for 21 mln euro ( $ 30.3 mln ) in September 2007 .""",
]

# %% [markdown]
# ## 3. Define Spark NLP pipeline

# %%
document = DocumentAssembler()\
    .setInputCol("text")\
    .setOutputCol("document")

embeddings = BertSentenceEmbeddings\
    .pretrained('sent_bert_wiki_books_sst2', 'en') \
    .setInputCols(["document"])\
    .setOutputCol("sentence_embeddings")

sentimentClassifier = ClassifierDLModel.pretrained("classifierdl_bertwiki_finance_sentiment", "en") \
  .setInputCols(["sentence_embeddings"]) \
  .setOutputCol("class_")

financial_sentiment_pipeline = Pipeline(
    stages=[document,
            embeddings,
            sentimentClassifier])
# Out:
# sent_bert_wiki_books_sst2 download started this may take some time.
# Approximate size to download 389.7 MB
# [OK!]
# classifierdl_bertwiki_finance_sentiment download started this may take some time.
# Approximate size to download 22.5 MB
# [OK!]

# %% [markdown]
# ## 4. Run the pipeline

# %%
df = spark.createDataFrame(text_list, StringType()).toDF("text")
result = financial_sentiment_pipeline.fit(df).transform(df)
# Out:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/serializers.py", line 458, in dumps
#     return cloudpickle.dumps(obj, pickle_protocol)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 73, in dumps
#     cp.dump(obj)
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 602, in dump
#     return Pickler.dump(self, obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 692, in reducer_override
#     return self._function_reduce(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 565, in _function_reduce
#     return self._dynamic_function_reduce(obj)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 546, in _dynamic_function_reduce
#     state = _function_getstate(func)
#             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py", line 157, in _function_getstate
#     f_globals_ref = _extract_code_globals(func.__code__)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle.py", line 334, in _extract_code_globals
#     out_names = {names[oparg]: None for _, oparg in _walk_global_ops(co)}
#                  ~~~~~^^^^^^^
# IndexError: tuple index out of range
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pyspark/serializers.py in dumps(self, obj)
#     457         try:
# --> 458             return cloudpickle.dumps(obj, pickle_protocol)
#     459         except pickle.PickleError:
#
# /usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py in dumps(obj, protocol, buffer_callback)
#      72             )
# ---> 73             cp.dump(obj)
#      74             return file.getvalue()
#
# /usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py in dump(self, obj)
#     601         try:
# --> 602             return Pickler.dump(self, obj)
#     603         except RuntimeError as e:
#
# /usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py in reducer_override(self, obj)
#     691             elif isinstance(obj, types.FunctionType):
# --> 692                 return self._function_reduce(obj)
#     693             else:
#
# /usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py in _function_reduce(self, obj)
#     564         else:
# --> 565             return self._dynamic_function_reduce(obj)
#     566
#
# /usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py in _dynamic_function_reduce(self, func)
#     545         newargs = self._function_getnewargs(func)
# --> 546         state = _function_getstate(func)
#     547         return (types.FunctionType, newargs, state, None, None,
#
# /usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle_fast.py in _function_getstate(func)
#     156
# --> 157     f_globals_ref = _extract_code_globals(func.__code__)
#     158     f_globals = {k: func.__globals__[k] for k in f_globals_ref if k in
#
# /usr/local/lib/python3.12/dist-packages/pyspark/cloudpickle/cloudpickle.py in _extract_code_globals(co)
#     333         # non-deterministic pickle bytes as a results.
# --> 334         out_names = {names[oparg]: None for _, oparg in _walk_global_ops(co)}
#     335
#
# IndexError: tuple index out of range
#
# During handling of the above exception, another exception occurred:
#
# PicklingError                             Traceback (most recent call last)
# /tmp/ipython-input-3705547960.py in <cell line: 0>()
# ----> 1 df = spark.createDataFrame(text_list, StringType()).toDF("text")
#       2 result = financial_sentiment_pipeline.fit(df).transform(df)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in createDataFrame(self, data, schema, samplingRatio, verifySchema)
#     892                 data, schema, samplingRatio, verifySchema
#     893             )
# --> 894         return self._create_dataframe(
#     895             data, schema, samplingRatio, verifySchema  # type: ignore[arg-type]
#     896         )
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in _create_dataframe(self, data, schema, samplingRatio, verifySchema)
#     936             rdd, struct = self._createFromLocal(map(prepare, data), schema)
#     937         assert self._jvm is not None
# --> 938         jrdd = self._jvm.SerDeUtil.toJavaArray(rdd._to_java_object_rdd())
#     939         jdf = self._jsparkSession.applySchemaToPythonRDD(jrdd.rdd(), struct.json())
#     940         df = DataFrame(jdf, self)
#
# /usr/local/lib/python3.12/dist-packages/pyspark/rdd.py in _to_java_object_rdd(self)
#    3111         assert self.ctx._jvm is not None
#    3112
# -> 3113         return self.ctx._jvm.SerDeUtil.pythonToJava(rdd._jrdd, True)
#    3114
#    3115     def countApprox(self, timeout: int, confidence: float = 0.95) -> int:
#
# /usr/local/lib/python3.12/dist-packages/pyspark/rdd.py in _jrdd(self)
#    3503             profiler = None
#    3504
# -> 3505         wrapped_func = _wrap_function(
#    3506             self.ctx, self.func, self._prev_jrdd_deserializer, self._jrdd_deserializer, profiler
#    3507         )
#
# /usr/local/lib/python3.12/dist-packages/pyspark/rdd.py in _wrap_function(sc, func, deserializer, serializer, profiler)
#    3360     assert serializer, "serializer should not be empty"
#    3361     command = (func, profiler, deserializer, serializer)
# -> 3362     pickled_command, broadcast_vars, env, includes = _prepare_for_python_RDD(sc, command)
#    3363     assert sc._jvm is not None
#    3364     return sc._jvm.PythonFunction(
#
# /usr/local/lib/python3.12/dist-packages/pyspark/rdd.py in _prepare_for_python_RDD(sc, command)
#    3343     # the serialized command will be compressed by broadcast
#    3344     ser = CloudPickleSerializer()
# -> 3345     pickled_command = ser.dumps(command)
#    3346     assert sc._jvm is not None
#    3347     if len(pickled_command) > sc._jvm.PythonUtils.getBroadcastThreshold(sc._jsc):  # Default 1M
#
# /usr/local/lib/python3.12/dist-packages/pyspark/serializers.py in dumps(self, obj)
#     466                 msg = "Could not serialize object: %s: %s" % (e.__class__.__name__, emsg)
#     467             print_exec(sys.stderr)
# --> 468             raise pickle.PicklingError(msg)
#     469
#     470     def loads(self, obj, encoding="bytes"):
#
# PicklingError: Could not serialize object: IndexError: tuple index out of range

# %% [markdown]
# ## 5. Visualize results

# %%
result.select(F.explode(F.arrays_zip(result.document.result,
                                     result.class_.result)).alias("cols")) \
      .select(F.expr("cols['1']").alias("class"),
              F.expr("cols['0']").alias("document")).show(truncate=False)
